# %%
i=0
while i<5:
  print(i)
  i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
liste=[4,7,3,8,0]
for j in liste:
  print(j)
# Out:
# 4
# 7
# 3
# 8
# 0

# %%
k=0
while k < len(liste):
  print(liste[k])
  k +=1
# Out:
# 4
# 7
# 3
# 8
# 0
