# %%
'abc'
# Out:
# 'abc'

# %%
"cba"
# Out:
# 'cba'

# %%
"""bca"""
# Out:
# 'bca'

# %%
a="arkadias"
a[-1]
# Out:
# 's'

# %%
a[2:5]
# Out:
# 'kad'

# %%
a[:5]
# Out:
# 'arkad'

# %%
a[:]
# Out:
# 'arkadias'

# %%
a[::2]
# Out:
# 'akda'

# %%
a[::-1]
# Out:
# 'saidakra'

# %%
len(a)
# Out:
# 8

# %%
a+a+a
# Out:
# 'arkadiasarkadiasarkadias'

# %%
a*2
# Out:
# 'arkadiasarkadias'
