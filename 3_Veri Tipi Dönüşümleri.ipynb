# %%
a=2
float(a)
# Out:
# 2.0

# %%
b=2.3
int(b)
# Out:
# 2

# %%
c=123
d=str(c)
d*3
# Out:
# '123123123'

# %%
e="123.4"
float(e)
# Out:
# 123.4

# %%
f="567,8"
t=float(f.replace(',','.'))
print(t)
print(f)
print(3*t)
print(3*f)
# Out:
# 567.8
# 567,8
# 1703.3999999999999
# 567,8567,8567,8
