# %%
a=["cba",12,"dvc",3]
print(a)
print(type(a))
print(len(a))
# Out:
# ['cba', 12, 'dvc', 3]
# <class 'list'>
# 4

# %%
b=[]
c=list()
print(len(b),len(c),sep="\n")
# Out:
# 0
# 0

# %%
d=list("colabresarch")
print(len(d),"\n{}".format(d))
# Out:
# 12
# ['c', 'o', 'l', 'a', 'b', 'r', 'e', 's', 'a', 'r', 'c', 'h']

# %%
print(d[0],d[-1],d[::-1],d[:5],sep="\n")
# Out:
# c
# h
# ['h', 'c', 'r', 'a', 's', 'e', 'r', 'b', 'a', 'l', 'o', 'c']
# ['c', 'o', 'l', 'a', 'b']

# %%
print(*d,sep="")
f=str(print(*d,sep=""))
print(f)
# Out:
# colabresarch
# colabresarch
# None

# %%
t=[1,2,3,4,5]
t.append(6)
print(t)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
t=[1,2,3,4,5]
t.pop() #pop içerisine indis yazılmazsa son elemanı çıkartır.
print(t)
t.pop(2)
print(t)
# Out:
# [1, 2, 3, 4]
# [1, 2, 4]

# %%
o=[123,432,531,23,546]
u=["a","reqwec","lumk","kn"]
o.sort()
u.sort()
print(o,u,sep="\n")
o.sort(reverse = True)
print(o)
# Out:
# [23, 123, 432, 531, 546]
# ['a', 'kn', 'lumk', 'reqwec']
# [546, 531, 432, 123, 23]
