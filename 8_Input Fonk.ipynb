# %%
a=input("deger giriniz:")
print(type(a))
# Out:
# deger giriniz:2
# <class 'str'>

# %%
b=int(input("sayı gir:"))
print(3*b)
# Out:
# sayı gir:3
# 9

# %%
c=int(input("sayı gir:"))
# Out:
# sayı gir:asd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e91c20d5eeb1> in <module>()
# ----> 1 c=int(input("sayı gir:"))
#
# ValueError: invalid literal for int() with base 10: 'asd'

# %%
try:
  d=int(input("sayı gir:"))
  print(d)
except ValueError:
  print("type int koşulunu sağlayacak şekilde bir sayı giriniz.")
# Out:
# sayı gir:asd
# type int koşulunu sağlayacak şekilde bir sayı giriniz.
