# %% [markdown]
# Toplama işareti +
#
# Çıkarma işareti -
#
# Çarpma işareti *
#
# Bölme işareti /   (sonucu ondalıklı sayı olarak verir.)
#
# Tam sayı bölmesi //  (ondalık kısmını vermez.)
#
# Kalanı bulma %
#
# Üs alma **

# %%
 3 + 4
# Out:
# 7

# %%
4-2
# Out:
# 2

# %%
3*3
# Out:
# 9

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
8**(1/2)
# Out:
# 2.8284271247461903

# %%
8**(1/3)
# Out:
# 2.0
