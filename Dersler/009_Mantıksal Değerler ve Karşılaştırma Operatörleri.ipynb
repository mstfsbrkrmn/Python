# %%
a,b=True,False
type(a)
# Out:
# bool

# %%
bool(0)
# Out:
# False

# %%
bool(-1)
# Out:
# True

# %% [markdown]
# bool(0) ve bool(0.0) harici True'dur.

# %%
a = None # değeri henüz atanmamış.

# %% [markdown]
# == eşittir
#
# != eşit değildir
#
# < soldaki değer sağdaki değerden küçüktür
#
# \> soldaki değer sağdaki değerden büyüktür
#
# <= soldaki değer sağdaki değerden küçük veya eşittir
#
# \>= soldaki değer sağdaki değerden büyük veya eşittir
