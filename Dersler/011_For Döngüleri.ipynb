# %%
3 in {3,4,5}
# Out:
# True

# %%
2 in [3,4]
# Out:
# False

# %%
"e" in "Hello"
# Out:
# True

# %%
liste1 = [6,5,7,8]
for i in liste1:
  print(i)
# Out:
# 6
# 5
# 7
# 8

# %%
s = "Halo"
for k in s:
  print(k)
# Out:
# H
# a
# l
# o

# %%
liste2 = [[4,5],[6,7],[9,0]]
for l in liste2:
  print(l)
# Out:
# [4, 5]
# [6, 7]
# [9, 0]

# %%
for j,p in liste2:
  print(j,p)
# Out:
# 4 5
# 6 7
# 9 0

# %%
szlk={"first":234,"second":453,"third":"estas tonne"}
for q in szlk:
  print(q)
# Out:
# first
# second
# third

# %%
for q,w in szlk.items():
  print(q,w)
# Out:
# first 234
# second 453
# third estas tonne
