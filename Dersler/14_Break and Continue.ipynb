# %%
i=0
while i<10:
  print(i)
  i+=1
  if i==6:
    break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
i=0
print("q harfini girene kadar devam edecek.")
while True:
  a=input("harf gir:")
  print(a)
  if a=="q":
    break
  i+=1
# Out:
# q harfini girene kadar devam edecek.
# harf gir:v
# v
# harf gir:b
# b
# harf gir:c
# c
# harf gir:q
# q

# %%
i=0
while i<10:
  if i==6:
    i+=1
    continue
  print(i)
  i+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 7
# 8
# 9
