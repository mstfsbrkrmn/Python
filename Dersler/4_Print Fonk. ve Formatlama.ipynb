# %%
type(34)
# Out:
# int

# %%
type(3.4)
# Out:
# float

# %%
type("asc")
# Out:
# str

# %%
a="asd"
type(a)
print(type(a))
# Out:
# <class 'str'>

# %%
print(23,43,64,22)
# Out:
# 23 43 64 22

# %%
print(23,43,64,22,sep=".")
# Out:
# 23.43.64.22

# %%
print("23\n","43\t",64,22,sep="")
# Out:
# 23
# 43	6422

# %%
print(*"tarankru")
# Out:
# t a r a n k r u

# %%
print(*"tarankru",sep="/")
# Out:
# t/a/r/a/n/k/r/u

# %% [markdown]
# ## FORMATLAMA

# %%
a=2
b=3
print("{} + {} = {} ".format(a,b,a+b))
# Out:
# 2 + 3 = 5

# %%
print(a,"+",b,"=",a+b)
# Out:
# 2 + 3 = 5

# %%
print("{2} - {1} = {0}".format(a,b,a+b))
# Out:
# 5 - 3 = 2

# %%
c=3.1465 # .2f gibi kısaltma yapıldığında sayıyı yuvarlıyor. C'deki gibi kesmiyor.
e=2.7128
print("c={:.2f}\ne={:.2f}".format(c,e))
# Out:
# c=3.15
# e=2.71
