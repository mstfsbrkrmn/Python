# %% [markdown]
# a=[1,2]  dizi tanımlası
#
# a=(1,2)  demet tanımlaması
#
# a={'1':"bir",'2':"iki"}  sözlük tanımlaması

# %%
sozluk = {'1':"bir",'2':"iki"}
type(sozluk)
# Out:
# dict

# %%
sozluk["3"]="üç"
sozluk["yedi"]=7
sozluk["altı"]=6
sozluk
# Out:
# {'1': 'bir', '2': 'iki', '3': 'üç', 'altı': 6, 'yedi': 7}

# %% [markdown]
# **Sözlükler, listeler ve demetler gibi sıralı değildirler.**

# %%
sozluk.keys()
# Out:
# dict_keys(['1', '2', '3', 'yedi', 'altı'])

# %%
sozluk.values()
# Out:
# dict_values(['bir', 'iki', 'üç', 7, 6])

# %%
sozluk.items()
# Out:
# dict_items([('1', 'bir'), ('2', 'iki'), ('3', 'üç'), ('yedi', 7), ('altı', 6)])

# %%
a=3
sozluk["yeni_gelen"]=a
sozluk
# Out:
# {'1': 'bir', '2': 'iki', '3': 'üç', 'altı': 6, 'yedi': 7, 'yeni_gelen': 3}

# %%
for a,b in sozluk.items():
  print(a,b)
# Out:
# 1 bir
# 2 iki
# 3 üç
# yedi 7
# altı 6
# yeni_gelen 3
