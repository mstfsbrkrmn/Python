# %%
1 == 2 and 2 == 2
# Out:
# False

# %%
2 != 3 or 1 == 2
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
2 < 3 and 8 < 9 or 3 < 2 and 3 < 9 and 9 < 2
# T and T or F and T and F
# T or F
# önce and leri yapıyor sonra or
# Out:
# True
